# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from config import weather_api_key
import requests
import time
from datetime import datetime

# %%
lats = np.random.uniform(-90, 90, size=1500)
lngs = np.random.uniform(-180,180, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
cities = {citipy.nearest_city(*coords).city_name for coords in coordinates}

# %%
cities
# Out:
# {'adrar',
#  'airai',
#  'albany',
#  'alekseyevka',
#  'alice town',
#  'alihe',
#  'alofi',
#  'altagracia de orituco',
#  'altamont',
#  'altos',
#  'alyangula',
#  'amahai',
#  'amderma',
#  'amga',
#  'amudat',
#  'anadyr',
#  'anchorage',
#  'ancud',
#  'andenes',
#  'angra dos reis',
#  'anshun',
#  'antalaha',
#  'arlit',
#  'arraial do cabo',
#  'asau',
#  'asifabad',
#  'asyut',
#  'atar',
#  'athens',
#  'attawapiskat',
#  'atuona',
#  'avarua',
#  'avera',
#  'awjilah',
#  'bagdarin',
#  'baghdad',
#  'bahraich',
#  'bambanglipuro',
#  'bambous virieux',
#  'bandarbeyla',
#  'bara',
#  'barawe',
#  'barbar',
#  'bardsir',
#  'barentsburg',
#  'barrow',
#  'basco',
#  'bastia',
#  'beipiao',
#  'beloha',
#  'belushya guba',
#  'bend',
#  'bengkulu',
#  'benjamin constant',
#  'benoy',
#  'berikulskiy',
#  'beringovskiy',
#  'berlevag',
#  'bernalillo',
#  'bethel',
#  'bilibino',
#  'bilma',
#  'biltine',
#  'bintulu',
#  'bluff',
#  'bocaranga',
#  'bokoro',
#  'bonavista',
#  'bonham',
#  'bonthe',
#  'bonwapitse',
#  'bredasdorp',
#  'broome',
#  'bud',
#  'buin',
#  'bulgan',
#  'bullhead city',
#  'buon me thuot',
#  'bur gabo',
#  'buri',
#  'burnie',
#  'busselton',
#  'buta',
#  'butaritari',
#  'byron bay',
#  'cabo san lucas',
#  'cairns',
#  'cape town',
#  'carahue',
#  'carauari',
#  'caravelas',
#  'cardston',
#  'carnarvon',
#  'castro',
#  'cayenne',
#  'centralia',
#  'chabahar',
#  'chagda',
#  'chegutu',
#  'chengde',
#  'cherskiy',
#  'chicama',
#  'chilakalurupet',
#  'chippewa falls',
#  'choix',
#  'chokurdakh',
#  'chota',
#  'chuy',
#  'cidreira',
#  'clarence town',
#  'clinton',
#  'clyde river',
#  'codrington',
#  'coihaique',
#  'coihueco',
#  'colesberg',
#  'concarneau',
#  'constitucion',
#  'contamana',
#  'copiapo',
#  'coquimbo',
#  'corn island',
#  'coruripe',
#  'dawson',
#  'deputatskiy',
#  'derzhavinsk',
#  'dhidhdhoo',
#  'diadema',
#  'didi lilo',
#  'diebougou',
#  'dikson',
#  'dingle',
#  'dinsor',
#  'do gonbadan',
#  'dogondoutchi',
#  'dolores',
#  'dunedin',
#  'dzaoudzi',
#  'dzhusaly',
#  'east london',
#  'egvekinot',
#  'ekuvukeni',
#  'el guayabito',
#  'eldorado',
#  'elmadag',
#  'emba',
#  'emporia',
#  'ende',
#  'eregli',
#  'esperance',
#  'eureka',
#  'faanui',
#  'fairbanks',
#  'fare',
#  'faya',
#  'fevralsk',
#  'flin flon',
#  'flinders',
#  'floro',
#  'fomboni',
#  'formoso do araguaia',
#  'fort nelson',
#  'fortuna',
#  'freeport',
#  'gambela',
#  'gazanjyk',
#  'general pico',
#  'general roca',
#  'georgetown',
#  'geraldton',
#  'gilgit',
#  'gimli',
#  'ginir',
#  'gizo',
#  'gola gokarannath',
#  'gold coast',
#  'grand river south east',
#  'grande-riviere',
#  'grindavik',
#  'guajara-mirim',
#  'guerrero negro',
#  'haines junction',
#  'half moon bay',
#  'hambantota',
#  'hasaki',
#  'havoysund',
#  'havre-saint-pierre',
#  'hendek',
#  'henties bay',
#  'hermanus',
#  'hilo',
#  'himmaste',
#  'hirara',
#  'hithadhoo',
#  'hobart',
#  'hobyo',
#  'hofn',
#  'hoi an',
#  'honiara',
#  'hovd',
#  'husavik',
#  'illoqqortoormiut',
#  'ilulissat',
#  'ingham',
#  'inhambane',
#  'iqaluit',
#  'iquique',
#  'isangel',
#  'itaueira',
#  'itoman',
#  'izumo',
#  'jaguaribe',
#  'jamestown',
#  'jatiroto',
#  'jinchang',
#  'jingdezhen',
#  'jiquipilas',
#  'jumilla',
#  'jvari',
#  'kadoshkino',
#  'kaeo',
#  'kahului',
#  'kaitangata',
#  'kamenskoye',
#  'kamina',
#  'kampot',
#  'kapaa',
#  'kapoeta',
#  'katangli',
#  'katha',
#  'katherine',
#  'katsuura',
#  'kavaratti',
#  'kavieng',
#  'kempele',
#  'kerzhenets',
#  'keshorai patan',
#  'khandyga',
#  'khatanga',
#  'kizukuri',
#  'klaksvik',
#  'knysna',
#  'kodiak',
#  'komsomolskiy',
#  'kongolo',
#  'koprivnica',
#  'korem',
#  'koumac',
#  'kovernino',
#  'kozan',
#  'kribi',
#  'kruisfontein',
#  'kuche',
#  'kuching',
#  'kununurra',
#  'kuopio',
#  'kushiro',
#  'kyren',
#  'kysyl-syr',
#  'la peca',
#  'la ronge',
#  'lac du bonnet',
#  'lagoa',
#  'laguna',
#  'langangen',
#  'las choapas',
#  'lasa',
#  'lavrentiya',
#  'le port',
#  'lebu',
#  'leningradskiy',
#  'les cayes',
#  'lexington',
#  'limbang',
#  'linjiang',
#  'little current',
#  'lixourion',
#  'lodja',
#  'loikaw',
#  'lolua',
#  'lompoc',
#  'longyearbyen',
#  'lorengau',
#  'los llanos de aridane',
#  'louisbourg',
#  'luancheng',
#  'luanda',
#  'luau',
#  'lucapa',
#  'luderitz',
#  'maceio',
#  'mahebourg',
#  'mahon',
#  'makat',
#  'malakal',
#  'malinyi',
#  'malpe',
#  'mamallapuram',
#  'mangrol',
#  'mantua',
#  'mar del plata',
#  'maragogi',
#  'marang',
#  'marcona',
#  'marsh harbour',
#  'matagami',
#  'matara',
#  'mataura',
#  'mayya',
#  'mazamari',
#  'mehamn',
#  'mehran',
#  'mentok',
#  'merauke',
#  'mergui',
#  'metro',
#  'meyungs',
#  'middle island',
#  'millinocket',
#  'mirante do paranapanema',
#  'montrose',
#  'moose factory',
#  'morristown',
#  'mount gambier',
#  'mount isa',
#  'mufumbwe',
#  'muros',
#  'myitkyina',
#  'mys shmidta',
#  'nabinagar',
#  'nabire',
#  'najran',
#  'nalut',
#  'nalvo',
#  'namatanai',
#  'namibe',
#  'nandgaon',
#  'nanortalik',
#  'nara',
#  'narsaq',
#  'naze',
#  'necochea',
#  'nemuro',
#  'neuquen',
#  'new norfolk',
#  'nguiu',
#  'ngunguru',
#  'niagara falls',
#  'nikolskoye',
#  'nishihara',
#  'nizhneyansk',
#  'nizhniy kuranakh',
#  'nome',
#  'norman wells',
#  'novi pazar',
#  'novobirilyussy',
#  'novopokrovka',
#  'nueva loja',
#  'numan',
#  'nunkini',
#  'obidos',
#  'oga',
#  'okato',
#  'okhotsk',
#  'olafsvik',
#  'opuwo',
#  'oranjemund',
#  'ostrovnoy',
#  'oussouye',
#  'oyama',
#  'ozinki',
#  'pachelma',
#  'pacific grove',
#  'padang',
#  'palabuhanratu',
#  'paldiski',
#  'palmer',
#  'pangkalanbuun',
#  'paragominas',
#  'parang',
#  'paucartambo',
#  'peniche',
#  'petropavlovsk-kamchatskiy',
#  'pevek',
#  'phonhong',
#  'phumi samraong',
#  'pietersburg',
#  'pisco',
#  'pleshanovo',
#  'ponta do sol',
#  'port alfred',
#  'port blair',
#  'port elizabeth',
#  'port hardy',
#  'port hedland',
#  'port lincoln',
#  'port townsend',
#  'port-gentil',
#  'porto walter',
#  'portobelo',
#  'portree',
#  'potosi',
#  'poum',
#  'prince rupert',
#  'provideniya',
#  'pueblo bello',
#  'puerto ayora',
#  'puerto colombia',
#  'puerto madryn',
#  'punta arenas',
#  'puri',
#  'qaanaaq',
#  'qostanay',
#  'quang ngai',
#  'quatre cocos',
#  'rawah',
#  'rawson',
#  'ribeira grande',
#  'ribeirao do pinhal',
#  'rikitea',
#  'rio branco',
#  'riyadh',
#  'roald',
#  'rocha',
#  'roma',
#  'romanovo',
#  'rovaniemi',
#  'rudnogorsk',
#  'ruidoso',
#  'rundu',
#  'rungata',
#  'sabang',
#  'saint george',
#  'saint-augustin',
#  'saint-georges',
#  'saint-joseph',
#  'saint-louis',
#  'saint-philippe',
#  'saint-pierre',
#  'sakakah',
#  'salalah',
#  'salamanca',
#  'saldanha',
#  'saleaula',
#  'salinopolis',
#  'samalaeulu',
#  'sambava',
#  'samusu',
#  'san cristobal',
#  'san julian',
#  'san rafael',
#  'santa fe',
#  'santana do paraiso',
#  'sao filipe',
#  'sao joao da barra',
#  'sao paulo de olivenca',
#  'sapao',
#  'saquena',
#  'saryozek',
#  'saskylakh',
#  'sassandra',
#  'scranton',
#  'sechura',
#  'sentyabrskiy',
#  'severo-kurilsk',
#  'shagonar',
#  'shakawe',
#  'shalinskoye',
#  'shaoguan',
#  'sharlyk',
#  'shinuhayr',
#  'shostka',
#  'simao dias',
#  'sioux lookout',
#  'sistranda',
#  'sitka',
#  'skalistyy',
#  'skibbereen',
#  'smidovich',
#  'soloneshnoye',
#  'sorong',
#  'sorvag',
#  'souillac',
#  'south sioux city',
#  'sovetskiy',
#  'soyo',
#  'srandakan',
#  'srednekolymsk',
#  'sretensk',
#  'staraya mayna',
#  'staryy nadym',
#  'stralsund',
#  'strand',
#  'suez',
#  'suntar',
#  'sur',
#  'susanville',
#  'sydney mines',
#  'sylvan lake',
#  'tahta',
#  'talara',
#  'talnakh',
#  'taltal',
#  'taolanaro',
#  'taoudenni',
#  'tarana',
#  'tasiilaq',
#  'tautira',
#  'tchaourou',
#  'tchollire',
#  'te anau',
#  'terrace bay',
#  'teya',
#  'thinadhoo',
#  'thompson',
#  'tibati',
#  'tiksi',
#  'tilichiki',
#  'tiznit',
#  'tocopilla',
#  'toftir',
#  'toliary',
#  'tommot',
#  'tongchuan',
#  'toplet',
#  'torbay',
#  'toronto',
#  'torres',
#  'touros',
#  'trat',
#  'tsihombe',
#  'tual',
#  'tuatapere',
#  'tubruq',
#  'tuktoyaktuk',
#  'tumannyy',
#  'tumen',
#  'tupik',
#  'tura',
#  'turayf',
#  'tutoia',
#  'udachnyy',
#  'ulladulla',
#  'umm durman',
#  'umzimvubu',
#  'upernavik',
#  'urdzhar',
#  'ushuaia',
#  'usinsk',
#  'ust-koksa',
#  'ust-nera',
#  'ust-tsilma',
#  'uvalde',
#  'uwayl',
#  'vaini',
#  'vaitape',
#  'vaitupu',
#  'valparaiso',
#  'vanimo',
#  'vao',
#  'vardo',
#  'venice',
#  'verkhnevilyuysk',
#  'vestmannaeyjar',
#  'victoria',
#  'vicuna',
#  'vikhorevka',
#  'vila',
#  'vila franca do campo',
#  'vila velha',
#  'villa corzo',
#  'visby',
#  'voh',
#  'vredendal',
#  'vrises',
#  'vulturu',
#  'wad madani',
#  'waggaman',
#  'wajir',
#  'walvis bay',
#  'wana',
#  'westpunt',
#  'whitehorse',
#  'williams lake',
#  'williamsport',
#  'wlodawa',
#  'wufeng',
#  'xining',
#  'xinzhi',
#  'yagodnoye',
#  'yangcun',
#  'yantzaza',
#  'yar-sale',
#  'yatou',
#  'yellowknife',
#  'yulara',
#  'yumen',
#  'yunjinghong',
#  'zhigansk',
#  'zlobin',
#  'zyryanka'}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 1 | bastia
# Processing Record 4 of Set 1 | talara
# Processing Record 5 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 1 | dinsor
# City not found. Skipping...
# Processing Record 8 of Set 1 | yunjinghong
# City not found. Skipping...
# Processing Record 9 of Set 1 | athens
# Processing Record 10 of Set 1 | bahraich
# Processing Record 11 of Set 1 | saint george
# Processing Record 12 of Set 1 | portobelo
# Processing Record 13 of Set 1 | bocaranga
# City not found. Skipping...
# Processing Record 14 of Set 1 | souillac
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | vestmannaeyjar
# Processing Record 17 of Set 1 | general pico
# Processing Record 18 of Set 1 | kyren
# Processing Record 19 of Set 1 | ancud
# Processing Record 20 of Set 1 | nalvo
# Processing Record 21 of Set 1 | wana
# Processing Record 22 of Set 1 | cardston
# Processing Record 23 of Set 1 | jaguaribe
# Processing Record 24 of Set 1 | husavik
# Processing Record 25 of Set 1 | ekuvukeni
# Processing Record 26 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 27 of Set 1 | broome
# Processing Record 28 of Set 1 | sao filipe
# Processing Record 29 of Set 1 | cabo san lucas
# Processing Record 30 of Set 1 | thinadhoo
# Processing Record 31 of Set 1 | hasaki
# Processing Record 32 of Set 1 | skibbereen
# Processing Record 33 of Set 1 | atuona
# Processing Record 34 of Set 1 | saryozek
# Processing Record 35 of Set 1 | malpe
# Processing Record 36 of Set 1 | okato
# Processing Record 37 of Set 1 | hilo
# Processing Record 38 of Set 1 | port townsend
# Processing Record 39 of Set 1 | carnarvon
# Processing Record 40 of Set 1 | benoy
# Processing Record 41 of Set 1 | ingham
# Processing Record 42 of Set 1 | ende
# Processing Record 43 of Set 1 | emba
# Processing Record 44 of Set 1 | bonthe
# Processing Record 45 of Set 1 | antalaha
# Processing Record 46 of Set 1 | izumo
# Processing Record 47 of Set 1 | clarence town
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | usinsk
# Processing Record 50 of Set 1 | alice town
# Processing Record 1 of Set 2 | malakal
# Processing Record 2 of Set 2 | teya
# Processing Record 3 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 2 | obidos
# Processing Record 5 of Set 2 | walvis bay
# Processing Record 6 of Set 2 | nandgaon
# Processing Record 7 of Set 2 | torbay
# Processing Record 8 of Set 2 | soloneshnoye
# Processing Record 9 of Set 2 | novopokrovka
# Processing Record 10 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 2 | ulladulla
# Processing Record 12 of Set 2 | new norfolk
# Processing Record 13 of Set 2 | staryy nadym
# Processing Record 14 of Set 2 | sao paulo de olivenca
# Processing Record 15 of Set 2 | marsh harbour
# Processing Record 16 of Set 2 | grindavik
# Processing Record 17 of Set 2 | luanda
# Processing Record 18 of Set 2 | pietersburg
# Processing Record 19 of Set 2 | prince rupert
# Processing Record 20 of Set 2 | saskylakh
# Processing Record 21 of Set 2 | phumi samraong
# City not found. Skipping...
# Processing Record 22 of Set 2 | sorong
# Processing Record 23 of Set 2 | dhidhdhoo
# Processing Record 24 of Set 2 | vila
# Processing Record 25 of Set 2 | katherine
# Processing Record 26 of Set 2 | opuwo
# Processing Record 27 of Set 2 | narsaq
# Processing Record 28 of Set 2 | salalah
# Processing Record 29 of Set 2 | eregli
# Processing Record 30 of Set 2 | najran
# Processing Record 31 of Set 2 | langangen
# City not found. Skipping...
# Processing Record 32 of Set 2 | saint-philippe
# Processing Record 33 of Set 2 | bokoro
# Processing Record 34 of Set 2 | lixourion
# Processing Record 35 of Set 2 | toplet
# Processing Record 36 of Set 2 | coquimbo
# Processing Record 37 of Set 2 | romanovo
# Processing Record 38 of Set 2 | buri
# Processing Record 39 of Set 2 | haines junction
# Processing Record 40 of Set 2 | tiznit
# Processing Record 41 of Set 2 | clyde river
# Processing Record 42 of Set 2 | chokurdakh
# Processing Record 43 of Set 2 | khandyga
# Processing Record 44 of Set 2 | laguna
# Processing Record 45 of Set 2 | naze
# Processing Record 46 of Set 2 | fevralsk
# City not found. Skipping...
# Processing Record 47 of Set 2 | jiquipilas
# Processing Record 48 of Set 2 | diadema
# Processing Record 49 of Set 2 | bonwapitse
# Processing Record 50 of Set 2 | baghdad
# Processing Record 1 of Set 3 | choix
# Processing Record 2 of Set 3 | tautira
# Processing Record 3 of Set 3 | ruidoso
# Processing Record 4 of Set 3 | mayya
# Processing Record 5 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 6 of Set 3 | port-gentil
# Processing Record 7 of Set 3 | limbang
# Processing Record 8 of Set 3 | coihueco
# Processing Record 9 of Set 3 | chengde
# Processing Record 10 of Set 3 | kaitangata
# Processing Record 11 of Set 3 | dikson
# Processing Record 12 of Set 3 | sioux lookout
# Processing Record 13 of Set 3 | kapaa
# Processing Record 14 of Set 3 | tumen
# Processing Record 15 of Set 3 | amudat
# Processing Record 16 of Set 3 | grande-riviere
# City not found. Skipping...
# Processing Record 17 of Set 3 | novobirilyussy
# Processing Record 18 of Set 3 | hofn
# Processing Record 19 of Set 3 | ozinki
# Processing Record 20 of Set 3 | qostanay
# Processing Record 21 of Set 3 | korem
# Processing Record 22 of Set 3 | chota
# Processing Record 23 of Set 3 | south sioux city
# Processing Record 24 of Set 3 | sovetskiy
# Processing Record 25 of Set 3 | valparaiso
# Processing Record 26 of Set 3 | benjamin constant
# Processing Record 27 of Set 3 | millinocket
# Processing Record 28 of Set 3 | alofi
# Processing Record 29 of Set 3 | georgetown
# Processing Record 30 of Set 3 | buon me thuot
# City not found. Skipping...
# Processing Record 31 of Set 3 | port blair
# Processing Record 32 of Set 3 | knysna
# Processing Record 33 of Set 3 | ponta do sol
# Processing Record 34 of Set 3 | pueblo bello
# Processing Record 35 of Set 3 | kizukuri
# Processing Record 36 of Set 3 | geraldton
# Processing Record 37 of Set 3 | lorengau
# Processing Record 38 of Set 3 | whitehorse
# Processing Record 39 of Set 3 | mufumbwe
# Processing Record 40 of Set 3 | port lincoln
# Processing Record 41 of Set 3 | kamina
# Processing Record 42 of Set 3 | copiapo
# Processing Record 43 of Set 3 | gola gokarannath
# Processing Record 44 of Set 3 | ribeira grande
# Processing Record 45 of Set 3 | yar-sale
# Processing Record 46 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 47 of Set 3 | roald
# Processing Record 48 of Set 3 | linjiang
# Processing Record 49 of Set 3 | palmer
# Processing Record 50 of Set 3 | asyut
# Processing Record 1 of Set 4 | kavieng
# Processing Record 2 of Set 4 | victoria
# Processing Record 3 of Set 4 | faanui
# Processing Record 4 of Set 4 | neuquen
# Processing Record 5 of Set 4 | gilgit
# Processing Record 6 of Set 4 | kribi
# Processing Record 7 of Set 4 | turayf
# Processing Record 8 of Set 4 | alekseyevka
# Processing Record 9 of Set 4 | bambous virieux
# Processing Record 10 of Set 4 | roma
# Processing Record 11 of Set 4 | little current
# Processing Record 12 of Set 4 | bandarbeyla
# Processing Record 13 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 14 of Set 4 | mount isa
# Processing Record 15 of Set 4 | lebu
# Processing Record 16 of Set 4 | avera
# Processing Record 17 of Set 4 | fort nelson
# Processing Record 18 of Set 4 | namibe
# Processing Record 19 of Set 4 | hirara
# Processing Record 20 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 4 | altos
# Processing Record 22 of Set 4 | el guayabito
# Processing Record 23 of Set 4 | sistranda
# Processing Record 24 of Set 4 | kampot
# Processing Record 25 of Set 4 | corn island
# Processing Record 26 of Set 4 | eureka
# Processing Record 27 of Set 4 | metro
# Processing Record 28 of Set 4 | kerzhenets
# City not found. Skipping...
# Processing Record 29 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 4 | bethel
# Processing Record 31 of Set 4 | nueva loja
# Processing Record 32 of Set 4 | nunkini
# Processing Record 33 of Set 4 | pachelma
# Processing Record 34 of Set 4 | caravelas
# Processing Record 35 of Set 4 | maceio
# Processing Record 36 of Set 4 | marang
# Processing Record 37 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 38 of Set 4 | taoudenni
# Processing Record 39 of Set 4 | castro
# Processing Record 40 of Set 4 | airai
# Processing Record 41 of Set 4 | nabire
# Processing Record 42 of Set 4 | isangel
# Processing Record 43 of Set 4 | tahta
# Processing Record 44 of Set 4 | nishihara
# Processing Record 45 of Set 4 | nome
# Processing Record 46 of Set 4 | visby
# Processing Record 47 of Set 4 | bambanglipuro
# Processing Record 48 of Set 4 | bud
# Processing Record 49 of Set 4 | shostka
# Processing Record 50 of Set 4 | kununurra
# Processing Record 1 of Set 5 | vanimo
# Processing Record 2 of Set 5 | ngunguru
# Processing Record 3 of Set 5 | kaeo
# Processing Record 4 of Set 5 | namatanai
# Processing Record 5 of Set 5 | port elizabeth
# Processing Record 6 of Set 5 | bend
# Processing Record 7 of Set 5 | peniche
# Processing Record 8 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 5 | klaksvik
# Processing Record 10 of Set 5 | bagdarin
# Processing Record 11 of Set 5 | kuopio
# Processing Record 12 of Set 5 | lac du bonnet
# Processing Record 13 of Set 5 | chicama
# Processing Record 14 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 15 of Set 5 | contamana
# Processing Record 16 of Set 5 | oranjemund
# Processing Record 17 of Set 5 | arraial do cabo
# Processing Record 18 of Set 5 | shagonar
# Processing Record 19 of Set 5 | sao joao da barra
# Processing Record 20 of Set 5 | floro
# Processing Record 21 of Set 5 | zhigansk
# Processing Record 22 of Set 5 | barrow
# Processing Record 23 of Set 5 | quatre cocos
# Processing Record 24 of Set 5 | beloha
# Processing Record 25 of Set 5 | vardo
# Processing Record 26 of Set 5 | toronto
# Processing Record 27 of Set 5 | guerrero negro
# Processing Record 28 of Set 5 | bardsir
# Processing Record 29 of Set 5 | vikhorevka
# Processing Record 30 of Set 5 | kahului
# Processing Record 31 of Set 5 | stralsund
# Processing Record 32 of Set 5 | sretensk
# Processing Record 33 of Set 5 | carahue
# Processing Record 34 of Set 5 | sapao
# City not found. Skipping...
# Processing Record 35 of Set 5 | necochea
# Processing Record 36 of Set 5 | wufeng
# Processing Record 37 of Set 5 | asau
# Processing Record 38 of Set 5 | nizhniy kuranakh
# Processing Record 39 of Set 5 | bara
# Processing Record 40 of Set 5 | dawson
# Processing Record 41 of Set 5 | zyryanka
# Processing Record 42 of Set 5 | verkhnevilyuysk
# Processing Record 43 of Set 5 | ust-tsilma
# Processing Record 44 of Set 5 | srandakan
# Processing Record 45 of Set 5 | altagracia de orituco
# Processing Record 46 of Set 5 | riyadh
# Processing Record 47 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 5 | jumilla
# Processing Record 49 of Set 5 | gold coast
# Processing Record 50 of Set 5 | sur
# Processing Record 1 of Set 6 | butaritari
# Processing Record 2 of Set 6 | vao
# Processing Record 3 of Set 6 | atar
# Processing Record 4 of Set 6 | ushuaia
# Processing Record 5 of Set 6 | vredendal
# Processing Record 6 of Set 6 | avarua
# Processing Record 7 of Set 6 | matara
# Processing Record 8 of Set 6 | busselton
# Processing Record 9 of Set 6 | esperance
# Processing Record 10 of Set 6 | paragominas
# Processing Record 11 of Set 6 | emporia
# Processing Record 12 of Set 6 | ribeirao do pinhal
# City not found. Skipping...
# Processing Record 13 of Set 6 | gazanjyk
# Processing Record 14 of Set 6 | thompson
# Processing Record 15 of Set 6 | mahebourg
# Processing Record 16 of Set 6 | do gonbadan
# Processing Record 17 of Set 6 | mazamari
# Processing Record 18 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 19 of Set 6 | qaanaaq
# Processing Record 20 of Set 6 | las choapas
# Processing Record 21 of Set 6 | wad madani
# Processing Record 22 of Set 6 | montrose
# Processing Record 23 of Set 6 | mangrol
# Processing Record 24 of Set 6 | bonavista
# Processing Record 25 of Set 6 | terrace bay
# Processing Record 26 of Set 6 | bilibino
# Processing Record 27 of Set 6 | salinopolis
# Processing Record 28 of Set 6 | umm durman
# City not found. Skipping...
# Processing Record 29 of Set 6 | cayenne
# Processing Record 30 of Set 6 | puri
# Processing Record 31 of Set 6 | novi pazar
# Processing Record 32 of Set 6 | merauke
# Processing Record 33 of Set 6 | oga
# Processing Record 34 of Set 6 | luancheng
# Processing Record 35 of Set 6 | kushiro
# Processing Record 36 of Set 6 | wajir
# Processing Record 37 of Set 6 | centralia
# Processing Record 38 of Set 6 | shinuhayr
# Processing Record 39 of Set 6 | chilakalurupet
# Processing Record 40 of Set 6 | pleshanovo
# Processing Record 41 of Set 6 | sabang
# Processing Record 42 of Set 6 | bengkulu
# Processing Record 43 of Set 6 | taltal
# Processing Record 44 of Set 6 | hoi an
# Processing Record 45 of Set 6 | albany
# Processing Record 46 of Set 6 | nalut
# Processing Record 47 of Set 6 | tommot
# Processing Record 48 of Set 6 | fairbanks
# Processing Record 49 of Set 6 | williams lake
# Processing Record 50 of Set 6 | severo-kurilsk
# Processing Record 1 of Set 7 | alyangula
# Processing Record 2 of Set 7 | angra dos reis
# Processing Record 3 of Set 7 | freeport
# Processing Record 4 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Record 5 of Set 7 | tiksi
# Processing Record 6 of Set 7 | le port
# Processing Record 7 of Set 7 | colesberg
# Processing Record 8 of Set 7 | tual
# Processing Record 9 of Set 7 | hendek
# Processing Record 10 of Set 7 | norman wells
# Processing Record 11 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 7 | vulturu
# Processing Record 13 of Set 7 | didi lilo
# Processing Record 14 of Set 7 | vaini
# Processing Record 15 of Set 7 | itaueira
# Processing Record 16 of Set 7 | carauari
# Processing Record 17 of Set 7 | asifabad
# Processing Record 18 of Set 7 | makat
# Processing Record 19 of Set 7 | upernavik
# Processing Record 20 of Set 7 | lompoc
# Processing Record 21 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 23 of Set 7 | bonham
# Processing Record 24 of Set 7 | clinton
# Processing Record 25 of Set 7 | san julian
# Processing Record 26 of Set 7 | flinders
# Processing Record 27 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 28 of Set 7 | concarneau
# Processing Record 29 of Set 7 | leningradskiy
# Processing Record 30 of Set 7 | basco
# Processing Record 31 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 7 | hobyo
# Processing Record 33 of Set 7 | sassandra
# Processing Record 34 of Set 7 | alihe
# Processing Record 35 of Set 7 | saint-louis
# Processing Record 36 of Set 7 | uvalde
# Processing Record 37 of Set 7 | anadyr
# Processing Record 38 of Set 7 | tocopilla
# Processing Record 39 of Set 7 | deputatskiy
# Processing Record 40 of Set 7 | westpunt
# City not found. Skipping...
# Processing Record 41 of Set 7 | egvekinot
# Processing Record 42 of Set 7 | mirante do paranapanema
# Processing Record 43 of Set 7 | venice
# Processing Record 44 of Set 7 | yatou
# Processing Record 45 of Set 7 | vila franca do campo
# Processing Record 46 of Set 7 | buta
# Processing Record 47 of Set 7 | faya
# Processing Record 48 of Set 7 | amga
# Processing Record 49 of Set 7 | san rafael
# Processing Record 50 of Set 7 | tubruq
# City not found. Skipping...
# Processing Record 1 of Set 8 | jatiroto
# Processing Record 2 of Set 8 | inhambane
# Processing Record 3 of Set 8 | tasiilaq
# Processing Record 4 of Set 8 | altamont
# Processing Record 5 of Set 8 | diebougou
# Processing Record 6 of Set 8 | xinzhi
# Processing Record 7 of Set 8 | adrar
# Processing Record 8 of Set 8 | lodja
# Processing Record 9 of Set 8 | zlobin
# Processing Record 10 of Set 8 | wlodawa
# Processing Record 11 of Set 8 | suntar
# Processing Record 12 of Set 8 | numan
# Processing Record 13 of Set 8 | sakakah
# Processing Record 14 of Set 8 | dunedin
# Processing Record 15 of Set 8 | port alfred
# Processing Record 16 of Set 8 | saint-joseph
# Processing Record 17 of Set 8 | rawah
# Processing Record 18 of Set 8 | vila velha
# Processing Record 19 of Set 8 | quang ngai
# Processing Record 20 of Set 8 | cherskiy
# Processing Record 21 of Set 8 | voh
# Processing Record 22 of Set 8 | jingdezhen
# Processing Record 23 of Set 8 | byron bay
# Processing Record 24 of Set 8 | arlit
# Processing Record 25 of Set 8 | bintulu
# Processing Record 26 of Set 8 | dingle
# Processing Record 27 of Set 8 | coihaique
# Processing Record 28 of Set 8 | salamanca
# Processing Record 29 of Set 8 | sitka
# Processing Record 30 of Set 8 | yantzaza
# Processing Record 31 of Set 8 | nikolskoye
# Processing Record 32 of Set 8 | santana do paraiso
# Processing Record 33 of Set 8 | kavaratti
# Processing Record 34 of Set 8 | awjilah
# Processing Record 35 of Set 8 | derzhavinsk
# Processing Record 36 of Set 8 | oyama
# Processing Record 37 of Set 8 | katha
# City not found. Skipping...
# Processing Record 38 of Set 8 | gizo
# Processing Record 39 of Set 8 | provideniya
# Processing Record 40 of Set 8 | jinchang
# Processing Record 41 of Set 8 | mahon
# Processing Record 42 of Set 8 | tongchuan
# Processing Record 43 of Set 8 | srednekolymsk
# Processing Record 44 of Set 8 | lavrentiya
# Processing Record 45 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 46 of Set 8 | lagoa
# Processing Record 47 of Set 8 | coruripe
# Processing Record 48 of Set 8 | constitucion
# Processing Record 49 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 50 of Set 8 | strand

# %%
len(city_data)

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_date_df = city_date_df[new_column_order]

# %%
output_data_file = "weather_data/cities.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
